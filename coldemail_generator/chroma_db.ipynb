# %%
import chromadb
client=chromadb.Client()
collection=client.create_collection(name='cold_email_db');

# %%
collection.add(
    documents=[
        "hello",
        "hi",
        "dengeyandi"
        
    ],
ids=['id1','id2','id3'])
# Out:
# C:\Users\yagnesh\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|████| 79.3M/79.3M [05:23<00:00, 257kiB/s]

# %%
collection.get()
# Out:
# {'ids': ['id1', 'id2', 'id3'],
#  'embeddings': None,
#  'documents': ['hello', 'hi', 'dengeyandi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None, None]}
